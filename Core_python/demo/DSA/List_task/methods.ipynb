# %%
#append, clear, copy, count, extend, index, insert, pop
#remove,reverse, sort


li = [10,20,30,40,50]


#adding
li.append(80)
li
# Out:
# [10, 20, 30, 40, 50, 80]

# %%
li.append([90,100])
li
# Out:
# [10, 20, 30, 40, 50, 80, [90, 100], [90, 100]]

# %%
#allows to add multiple element
li.extend([60,70])
li
# Out:
# [10, 20, 30, 40, 50, 80, [90, 100], [90, 100], 60, 70]

# %%
#add at given index

li.insert(3,'abc')
li
# Out:
# [10, 20, 30, 'abc', 40, 50, 80, [90, 100], [90, 100], 60, 70]

# %%
#remove

li.clear()
li
# Out:
# []

# %%
#pop method is used to remove element by usiing index
#by deafault it removes end element
li.pop()

li.pop(3)

# %%
#remove method is used to remove element by passing element
#it removes the first occurance of the element in list

li.remove(30)

# %%
li
# Out:
# [10, 20, 40, 50, 80]
