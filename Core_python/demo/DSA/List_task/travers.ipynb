# %%
li = [10,20,30,40]

for i in range(0,len(li)):
    print(li[i])
# Out:
# 10
# 20
# 30
# 40

# %%
li = [40,30,60,80,70]

mx = li[0]
for i in range(1,len(li)):
    if li[i] > mx:
        mx = li[i]

print(mx)
# Out:
# 80
