# %%
def add():
    num1 = int(input('"Enter number 1: '))
    num2 = int(input("Emter number 2: "))

    sum = num1 + num2

    print(f"Additon of {num1} and {num2} is {sum}")

add()
# Out:
# Additon of 79 and 78 is 157
