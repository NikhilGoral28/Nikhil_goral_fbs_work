# %%
add = lambda x, y : x+y

print(add(20,45))
# Out:
# 65

# %%
# map function

lst = [1,2,3,4,5,6,7,9,8]

print(lst)

res = map(lambda x: x**2, lst)

print(list(res))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 9, 8]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       5 print(lst)
#       7 res = map(lambda x: x**2, lst)
# ----> 9 print(list(res))
#
# TypeError: 'list' object is not callable

# %%
#filter function

lst = [1,2,3,4,5,6,7,8,9]

res = filter(lambda x: x >3, lst)

print(list(res))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       3 lst = [1,2,3,4,5,6,7,8,9]
#       5 res = filter(lambda x: x >3, lst)
# ----> 7 print(list(res))
#
# TypeError: 'list' object is not callable
